# %%
import pandas as pd
import datetime

# %%
df = pd.read_excel('crimenMeridaNOV2024.xlsx')

# %%
print(df.info())   # Muestra las primeras 5 filas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   codigo       37 non-null     object
#  1   fecha        37 non-null     datetime64[ns]
#  2   descripcion  37 non-null     object
#  3   ubicación    37 non-null     object
#  4   estado       37 non-null     object
#  5   impacto      37 non-null     object
#  6   conteo       37 non-null     float64
#  7   alerta       37 non-null     float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 2.4+ KB
# None
